# %% [markdown]
# # Ant Colony Optimization
#
# ### Introduction
#
# - ACO is inspired from the collective behaviors of ant colonies
#     - A colony of simple agents (the ants) communicate indirectly via dynamic modifications of their environment (trails of pheromones)
#
# - Ants navigate from nest to food source
#     - each ant moves at random
#     - pheromone is deposited on path
#     - ants detect leading ant’s path, inclined to follow
#     - more pheromone on path increases probability of path being followed
#
# - A shortest path is discovered via pheromone trails
#     - without a global vision
#
# _________________________________________________________________________________________________________________________
#
# <img src='images/1_1.PNG'>
# _________________________________________________________________________________________________________________________
#
# - Developed by Marco Dorigo (Milan, Italy), and others in early 1990s
# - Can be used for both Static and Dynamic Combinatorial optimization problems
# - Some common applications:
#      - Quadratic assignment problems
#      - Scheduling problems
#      - Dynamic routing problems in networks
#
# - Theoretical analysis difficult
#      - algorithm is based on a series of random decisions (by artificial ants)
#      - probability of decisions changes on each iteration
#
# - Convergence is guaranteed, although the speed is unknown
# _________________________________________________________________________________________________________________________
#
# - Ant Colony Optimization typically use to solve minimum cost problems.
#      - We usually have N nodes and A undirected arcs
# - There are two working modes for the ants:
# - Forward
#     - Memorize the path it has followed while searching for the destination node
# - Backwards.
#     - While moving backwards, the ants leave pheromones on the arcs they traversed
#
# _________________________________________________________________________________________________________________________
#
# - Ant System is the early ACO algorithm designed for the traveling salesman problem
# - Virtual “trail” accumulated on path segments
# - Starting from a node selected at random
# - Path selected at random
#     - based on amount of “trail” present on possible paths from starting node
#     - higher probability for paths with more “trail”
# - Ant reaches next node, selects next path
# - Continues until reaches starting node
# - Finished “tour” is a solution
# _________________________________________________________________________________________________________________________
#
# - A completed tour is analyzed for optimality
# - “Trail” amount adjusted to favor better solutions
#     - better solutions receive more trail
#     - worse solutions receive less trail
#     - higher probability of ant selecting path that is part of a better performing tour
# - Evaporation of pheromone: capability to forget bad solutions
# - New cycle is performed
# - Repeated until most ants select the same tour on every cycle (convergence to solution)
#
# _________________________________________________________________________________________________________________________
#
# <img src='images/1_2.PNG'>
#
# _________________________________________________________________________________________________________________________
#
# <img src='images/1_3.PNG'>
#
# _________________________________________________________________________________________________________________________
#
# <img src='images/1_4.PNG'>
#
# _________________________________________________________________________________________________________________________
#
# <img src='images/1_5.PNG'>
#
# _________________________________________________________________________________________________________________________
#
# <img src='images/1_6.PNG'>
#
# _________________________________________________________________________________________________________________________
#
# <img src='images/1_7.PNG'>
#
# _________________________________________________________________________________________________________________________
#
# <img src='images/1_8.PNG'>
#
# _________________________________________________________________________________________________________________________
#
# <img src='images/1_9.PNG'>
#
# _________________________________________________________________________________________________________________________
#
# <img src='images/1_10.PNG'>
#
# _________________________________________________________________________________________________________________________
#
#
# <img src='images/1_11.PNG'>
#
# _________________________________________________________________________________________________________________________
#
#
#
# <img src='images/1_12.PNG'>
#
# _________________________________________________________________________________________________________________________
#
#
#
# <img src='images/1_13.PNG'>
#
# _________________________________________________________________________________________________________________________
#
#
#
# <img src='images/1_14.PNG'>
#
# _________________________________________________________________________________________________________________________
#
#
#
# <img src='images/1_15.PNG'>
#
# _________________________________________________________________________________________________________________________
#
#
#
# <img src='images/1_16.PNG'>
#
# _________________________________________________________________________________________________________________________
#
#
#
# <img src='images/1_17.PNG'>
#
# _________________________________________________________________________________________________________________________
#
#
#
# <img src='images/1_18.PNG'>
#
# _________________________________________________________________________________________________________________________
#
#
#
# <img src='images/1_19.PNG'>
#
# _________________________________________________________________________________________________________________________
#
#
#
# <img src='images/1_20.PNG'>
#
# _________________________________________________________________________________________________________________________
